# %%
import bz2
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
import string
# Any results you write to the current directory are saved as output.

# %%
from tensorflow.python.keras import models, layers, optimizers
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# Getting The Data From The Sources

# %%
def get_labels_and_texts(file):
    labels = []
    texts = []
    for line in bz2.BZ2File(file):
        x = line.decode("utf-8")
        labels.append(int(x[9]) - 1)
        texts.append(x[10:].strip())
    return np.array(labels), texts
train_labels, train_texts = get_labels_and_texts('train.ft.txt.bz2')
test_labels, test_texts = get_labels_and_texts('test.ft.txt.bz2')

# %%
train_df=pd.DataFrame(list(zip(train_labels, train_texts)),columns =['Labels', 'Text'])
train_df
# Out:
#          Labels                                               Text
# 0             1  Stuning even for the non-gamer: This sound tra...
# 1             1  The best soundtrack ever to anything.: I'm rea...
# 2             1  Amazing!: This soundtrack is my favorite music...
# 3             1  Excellent Soundtrack: I truly like this soundt...
# 4             1  Remember, Pull Your Jaw Off The Floor After He...
# ...         ...                                                ...
# 3599995       0  Don't do it!!: The high chair looks great when...
# 3599996       0  Looks nice, low functionality: I have used thi...
# 3599997       0  compact, but hard to clean: We have a small ho...
# 3599998       0  what is it saying?: not sure what this book is...
# 3599999       1  Makes My Blood Run Red-White-And-Blue: I agree...
#
# [3600000 rows x 2 columns]

# %%
test_df=pd.DataFrame(list(zip(test_labels, test_texts)),columns =['Labels', 'Text'])
test_df
# Out:
#         Labels                                               Text
# 0            1  Great CD: My lovely Pat has one of the GREAT v...
# 1            1  One of the best game music soundtracks - for a...
# 2            0  Batteries died within a year ...: I bought thi...
# 3            1  works fine, but Maha Energy is better: Check o...
# 4            1  Great for the non-audiophile: Reviewed quite a...
# ...        ...                                                ...
# 399995       0  Unbelievable- In a Bad Way: We bought this Tho...
# 399996       0  Almost Great, Until it Broke...: My son reciev...
# 399997       0  Disappointed !!!: I bought this toy for my son...
# 399998       1  Classic Jessica Mitford: This is a compilation...
# 399999       0  Comedy Scene, and Not Heard: This DVD will be ...
#
# [400000 rows x 2 columns]

# %%
pos = []
neg = []
for l in train_df.Labels:
    if l == 0:
        pos.append(0)
        neg.append(1)
    elif l == 1:
        pos.append(1)
        neg.append(0)

# %%
train_df['Pos']= pos
train_df['Neg']= neg

# %%
train_df.head()
# Out:
#    Labels                                               Text  Pos  Neg
# 0       1  Stuning even for the non-gamer: This sound tra...    1    0
# 1       1  The best soundtrack ever to anything.: I'm rea...    1    0
# 2       1  Amazing!: This soundtrack is my favorite music...    1    0
# 3       1  Excellent Soundtrack: I truly like this soundt...    1    0
# 4       1  Remember, Pull Your Jaw Off The Floor After He...    1    0

# %% [markdown]
# Cleaning(1)

# %%
def remove_punct(text):
    text_nopunct = ''
    text_nopunct = re.sub('['+string.punctuation+']', '', text)
    return text_nopunct

train_df['Text_Clean'] = train_df['Text'].apply(lambda x: remove_punct(x))

# %% [markdown]
# Cleaning The Text Data

# %%
import re
NON_ALPHANUM = re.compile(r'[\W]')
NON_ASCII = re.compile(r'[^a-z0-1\s]')
def normalize_texts(texts):
    normalized_texts = []
    for text in texts:
        lower = text.lower()
        no_punctuation = NON_ALPHANUM.sub(r' ', lower)
        no_non_ascii = NON_ASCII.sub(r'', no_punctuation)
        normalized_texts.append(no_non_ascii)
    return normalized_texts
        
train_texts = normalize_texts(train_texts)
test_texts = normalize_texts(test_texts)

# %% [markdown]
# Splitting The Data Into Train And Validation Sets

# %%
from sklearn.model_selection import train_test_split
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_texts, train_labels, random_state=57643892, test_size=0.15)

# %% [markdown]
# tokenising The top 15000 words using keras tokeniser
# We fit it on the train set and apply to the other sets

# %%
MAX_FEATURES = 15000
tokenizer = Tokenizer(num_words=MAX_FEATURES)
tokenizer.fit_on_texts(train_texts)
train_texts = tokenizer.texts_to_sequences(train_texts)
val_texts = tokenizer.texts_to_sequences(val_texts)
test_texts = tokenizer.texts_to_sequences(test_texts)

# %% [markdown]
# we'll find the largest text and pad all the texts to that maximum length in order to make the dataset uniform

# %%
MAX_LENGTH = max(len(train_ex) for train_ex in train_texts)
train_texts = pad_sequences(train_texts, maxlen=MAX_LENGTH)
val_texts = pad_sequences(val_texts, maxlen=MAX_LENGTH)
test_texts = pad_sequences(test_texts, maxlen=MAX_LENGTH)

# %% [markdown]
# From tensorflow.keras a model has been built, a convulational network.
# There are many layers included in this network.
# The model summary given below details the network.

# %%
def build_model():
    sequences = layers.Input(shape=(MAX_LENGTH,))
    embedded = layers.Embedding(MAX_FEATURES, 128)(sequences)
    x = layers.Conv1D(128, 3, activation='relu')(embedded)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D(3)(x)
    x = layers.Conv1D(128, 3, activation='relu')(embedded)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D(3)(x)
    x = layers.Conv1D(128, 5, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D(5)(x)
    x = layers.Conv1D(128, 5, activation='relu')(x)
    x = layers.GlobalMaxPool1D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(100, activation='relu')(x)
    predictions = layers.Dense(1, activation='sigmoid')(x)
    model = models.Model(inputs=sequences, outputs=predictions)
    model.compile(
        optimizer='rmsprop',
        loss='binary_crossentropy',
        metrics=['binary_accuracy']
    )
    return model
    
model = build_model()

# %%
model.fit(
    train_texts, 
    train_labels, 
    batch_size=256,
    epochs=4,
    validation_data=(val_texts, val_labels), )
# Out:
# Epoch 1/4
# 11954/11954 [==============================] - 8558s 716ms/step - loss: 0.1603 - binary_accuracy: 0.9393 - val_loss: 0.1538 - val_binary_accuracy: 0.9441
# Epoch 2/4
# 11954/11954 [==============================] - 74711s 6s/step - loss: 0.1326 - binary_accuracy: 0.9516 - val_loss: 0.1331 - val_binary_accuracy: 0.9507
# Epoch 3/4
# 11954/11954 [==============================] - 15807s 1s/step - loss: 0.1251 - binary_accuracy: 0.9549 - val_loss: 0.1302 - val_binary_accuracy: 0.9527
# Epoch 4/4
# 11954/11954 [==============================] - 12162s 1s/step - loss: 0.1196 - binary_accuracy: 0.9573 - val_loss: 0.1284 - val_binary_accuracy: 0.9534

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 255)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 255, 128)          1920000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 253, 128)          49280
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 253, 128)          512
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 84, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 80, 128)           82048
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 80, 128)           512
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 12, 128)           82048
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               12900
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 2,147,401
# Trainable params: 2,146,889
# Non-trainable params: 512
# _________________________________________________________________

# %%
preds = model.predict(test_texts)
print('Accuracy on the test set: {:0.4}'.format(accuracy_score(test_labels, 1 * (preds > 0.5))))
print('F1 score on the test set: {:0.4}'.format(f1_score(test_labels, 1 * (preds > 0.5))))
print('ROC AUC score: {:0.4}'.format(roc_auc_score(test_labels, preds)))
# Out:
# Accuracy on the test set: 0.9531
# F1 score on the test set: 0.953
# ROC AUC score: 0.9888

# %%
1 * (preds > 0.5)
test_labels
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
test_texts
# Out:
# array([[   0,    0,    0, ...,   14,   12,  909],
#        [   0,    0,    0, ...,  369,  163,    6],
#        [   0,    0,    0, ...,   93, 3787,  437],
#        ...,
#        [   0,    0,    0, ..., 1593,   11,  442],
#        [   0,    0,    0, ..., 3073,    5,   52],
#        [   0,    0,    0, ...,    5,  203, 1331]])

# %%
new_df=pd.read_csv('amazon.csv')

# %%
new_df
# Out:
#       Unnamed: 0      tweet_id  \
# 0              0  1.270000e+18
# 1              1  1.270000e+18
# 2              2  1.270000e+18
# 3              3  1.270000e+18
# 4              4  1.270000e+18
# ...          ...           ...
# 3304        3327  1.270000e+18
# 3305        3328  1.270000e+18
# 3306        3329  1.270000e+18
# 3307        3330  1.270000e+18
# 3308        3332  1.270000e+18
#
#                                                    text  Sentiment
# 0     Yep, @amazon real easy to cancel now. I suppor...       -1.0
# 1     @amazon disgusting. Real classy Amazon.   @nyp...       -1.0
# 2     Check out this Amazon deal: #SamsungGalaxy S10...        0.0
# 3     RT @KennethCFilson: A Ripple In The Darkness b...        0.0
# 4     @midgets_levil @krokdrib @Jaxx702 @Marir65Ruiz...        0.0
# ...                                                 ...        ...
# 3304  RT @CaveManMike1: We need All Police Supporter...       -1.0
# 3305  @chessiblogs @kanwaldeep_k You just have to re...        1.0
# 3306  RT @Dreamwale90: We are currently on number 2 ...        1.0
# 3307  RT @mkjmc: Win a $500 @Amazon gift card from @...        1.0
# 3308  @TheAnuragOffice @amazon @JeffBezos @TheAnurag...        0.0
#
# [3309 rows x 4 columns]

# %%
new_texts = normalize_texts(new_df['text'])

# %%
new_texts
# Out:
# ['yep   amazon real easy to cancel now  i support all people  not blm rioters   hope all will cancel like i did ',
#  ' amazon disgusting  real classy amazon     nypost  njspba https   t co tpgrnonucq',
#  'check out this amazon deal   samsunggalaxy s10 lite new unlocked android cell phone   1gb of storage   gsm  amp  cdma   https   t co g0ltexoer',
#  'rt  kennethcfilson  a ripple in the darkness by kenneth c  filson   kindleunlimited  horror  revenge   camping      witch            ghost    love    ',
#  ' midgetslevil  krokdrib  jaxx0  marirruiz  gregmusselwhit  usmcmil0  dallasneedslung  amazon  pepsi   https   t co atchvlalhu',
#  '  gt  ibm will no longer offer  develop  or research  facialrecognition technology  arvindkrishna  verge  nist  amazon   https   t co nzxspqdm',
#  ' flipkartsupport on amazon i am also using fun zone  daily quiz   karigar   saheli   and  fortunewheel   occassion   https   t co kpxhknsnn',
#  'rt  lindsayromantic   romance  paperback  feelgoodfiction a summer bewitchment  the knight and the witch  by lindsay townsend https   t co   ',
#  ' google    pixela with gb memory cell phone  unlocked    just black   g00g by google https   t co wdcdpzfmv via  amazon',
#  ' midgetslevil  krokdrib  jaxx0  0texans  gregmusselwhit  usmcmil0  dallasneedslung  amazon  pepsi  ultabeauty   https   t co gilmmvfjk',
#  ' amazonhelp sir what is your team doing  you are here only because to make your customer fool or something else if   https   t co be1palhty',
#  'rt  ghouliachilds  1 day spooky countdown  advent calendar funko pre order now and save  10 00  amazon affiliate link  https   t co rvsndv  ',
#  ' lego   harrypotter   hogwartscastle 10 castle model building kit with harry potter figures gryffindor  hufflepu   https   t co uymlwjjbu',
#  'why is  amazon  s sorting tool so ass  like when you search for pricing  it removes 0  of the search',
#  'celebrate the seasons by suzy davies https   t co kmttrsxq via  amazon  poetry for  mg  fun  gifts to  cheer',
#  ' heathers  mayorjenny  amazon smells like a publicity stunt   he  s got no moral ground over anyone  jeff bozo is   https   t co butvxb',
#  '1 day spooky countdown  advent calendar funko pre order now and save  10 00  amazon affiliate link    https   t co acuqp0dt0i',
#  ' enforcelawsnyc  amazon there are some tax issues  many solved by not allowing overseas tax deferral after 01   b   https   t co rxcdtdob',
#  'gothic zombie mummy door knocker towel ring haunted house horror prop decorat    https   t co kzowvmevu via  amazon https   t co gczzlvav',
#  '   so  liberals at  ebay and  amazon both shared their support for  blm on their main page  i wonder if races were r   https   t co fudwxxhuj',
#  'rt  karlascents   rocconarva please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  ',
#  'journal with cute cartoon bulldog dog print cover  x blank diary with lined    https   t co n0emsvxgbu via  amazon',
#  'gothic poison beware skull coasters bar drink pirate party decorations pc se    https   t co nwckccxk via  amazon https   t co i1kbwdvkwo',
#  ' twitter  facebook  nfl  kingjames  nbaofficial  google  amazon  cher  oprah  barackobama  billdeblasio  ladygaga   https   t co qfaeuhtuxh',
#  'check out kapiva noni juice 1l   includes garcinia and ashwagandha for nutrient absorption   made from south indian   https   t co 0yqgtdy0q',
#  'i wanted to share promote this book by an amazing person  it just came out this past april  check it out on  amazon   https   t co tjfviwcxm',
#  ' stelimarf  kailunr  medicalbrunette  jesusrodriguezb  amazon fulfilled and shipped by amazon  read the fine print  try again ',
#  ' mevans1  amazon then google would know what amazon sold you  which amazon is tired of sharing ',
#  ' amazon i went on amazon to do some shopping  amp  this is what i saw on the home page  when i go to amazon i go to sho   https   t co uhzvhotux',
#  'check out this amazon deal   samsunggalaxys0plus g factory unlocked new android cell phone us version   1gb of   https   t co gpvyzpfb',
#  'universally yours  the phoenix by laura jean lysander https   t co m0xdycbik via  amazon',
#  'just saw this on amazon  all out war  the plot to destroy trump by klein  edward for  1  https   t co mrcpyulqv via  amazon  ',
#  'spooky orange halloween pumpkin boo crew socks jack o lantern novelty team ch    https   t co kiihdfjrax via  amazon https   t co vaqkjtd',
#  ' sierracool  beingfucking  from01to0  medicalbrunette  jesusrodriguezb  amazon their point is misguided  amazo   https   t co wynxohmaxq',
#  'rt  maciashmbrt  hailey s favorite flower decorative throw pillow collection 1   round  aqua     https   t co gmjyivx via  amazon',
#  'the air conditioner that was supposed to be delivered to me saturday  then today  evidently still hasn  t shipped    https   t co sdldesiwbd',
#  'deluxe psycho bloody help me shower curtain halloween bathroom prop decoratio    https   t co jpocdkuhe via  amazon https   t co ehej0gfwt',
#  'rt  stevens0   insaneclownprez  justinbaragona  acyn brought to you by   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pill  ',
#  'dear  amazon  it would be really handy if you included a photo of the item bought right here in the email  i buy so   https   t co bfdyhznh',
#  'jonathan silver scott  can you find their property brother book their are reading in this picture  amazon    https   t co pipqjl0x',
#  'check out life digital zed zed air ho silver 1 1 inch laptop  celeron gb 00gb   gb ssd windows 10 home integr   https   t co vbbixkwq1j',
#  'woodland confetti set  naturecuts  confetti  cutout  partysupplies  favors  decoration  party  event  birthday   https   t co aooovktovu',
#  ' women  authors  writing  fearless writing for women  extreme encoura    by susan gabriel for    https   t co xjxsvskhc via  amazon',
#  'notebook  horror cat    journal for  writing  college ruled size   x    110 pages  sponsored  amazon https   t co nmrxgylela',
#  ' harrypotter paperback box set  books 1   by mary grandpr  for   1 https   t co mbammzcmbi via  amazon',
#  'yesterday  my friend buy a watch on  amazon when he open the box that was empty when he call the customer care they   https   t co lqlvmnvwdy',
#  ' stelimarf  jacksimpson1  medicalbrunette  jesusrodriguezb  amazon yet amazon can and does regulate what is advert   https   t co zyfhti1glf',
#  'rt  midgetslevil   krokdrib  jaxx0  0texans  marirruiz  gregmusselwhit  usmcmil0  dallasneedslung  amazon  pepsi  ultabeauty  macco  ',
#  'rt  jondigbyauthor   numberone  bestseller in  amazon  history over 100  starreviews  uk https   t co nd0gbqgj                    us htt  ',
#  'win a  00  amazon gift card from  golfandcourse to spend on anything  https   t co uac0rbeq  golf  sweepstakes  contest  giveaway',
#  'rt  smita1   sanchitab1  warpedinglory  amazon yes geeta press is d only reliable source left  switch to tatacliq',
#  'rt  sanchitab1   warpedinglory  amazon that is why i prefer to buy all hindu books from geeta press gorakhpur  they are authentic and shoul  ',
#  ' amazon opening a brick and mortar  star store on  miamibeach s famed  lncolnrd  read more in  madeleinemarr s art   https   t co mpffslfv',
#  'black gothic damask brocade round table cloth topper halloween decoration i    https   t co ntzhsbdbm via  amazon https   t co ibtjkglljo',
#  'rt  warpedinglory   blindspot0  amazon yeah  since i live in devbhomi they are trying to send me this junk   further  this seller has pu  ',
#  'fyi  for any project manager out there  consider adding this to your library    the project management dictionary b   https   t co kkuehwcdd',
#  'rt  jondigbyauthor   numberone  bestseller in  amazon  history over 100  starreviews  uk https   t co nd0gbqgj                    us htt  ',
#  'check out this amazon deal  native body wash  pack   natural body wash women  amp  men   sls  amp  paraben free   cucumber   https   t co mkj0mm0paj',
#  ' amazon no wonder amazon supports rioters and out of control protests  has to be great for their home delivery busi   https   t co zfalyyl1c',
#  'rt  blindspot0   warpedinglory  amazon do you know how this works     they send you books according to your location  amp  the cultural uppe  ',
#  'battlefield z the collected adventures   a post apocalyptic action thriller  volume  by lowry  chris for   https   t co fanjajw0',
#  'rt  kt   warpedinglory  amazon  uppolice  11uttarpradesh  ghaziabadpolice  myogiadityanath  cmofficeup please take action against the  ',
#  ' rottenpapi billion dollar  jeffbezos and  amazon can t do anything to save their  twitch streamers from this stupidity   really ',
#  ' krokdrib  jaxx0  0texans  marirruiz  gregmusselwhit  usmcmil0  dallasneedslung  amazon  pepsi  ultabeauty   https   t co wzytixr1z',
#  ' majen  amazon it takes more time for their non unionized employees to grab a box appropriate for the size  and ch   https   t co i0zrysfgh',
#  ' harrypotter  the illustrated collection  books 1  boxed set  by kay  jim https   t co dtgowjqn via  amazon',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'rt  ashish   amazon  amazonca why can t you refund customer money on time  you deducted money while processing order and delivered dama  ',
#  ' amazon  kraftheinzco  bestbuy  proctergamble  petsmart  libertymutual  allstate  progressive  verizon  onepeloton   https   t co 1nzlx',
#  ' amazon you know what  you can suck it    i have a really good friend who ordered me coffee and donuts to cheer me   https   t co ebtjafulu',
#  'top  best digital instant read thermometers for kitchen   tech comparison https   t co lobdpw0i via  youtube   https   t co fy1biyeai',
#  'funky wild animal print paisley knee socks cheetah leopard black multi color     https   t co kgt0tbmjfn via  amazon https   t co qewxx0imj',
#  'pure organic  hemp oil  pack  000mg  100  natural  0ml drops  helps with loss of appetite quality  hemp oil seed   https   t co ytmjhzrs',
#  ' amazon sues to limit former  awscloud marketing vp brian hall  s new job at  googlecloud https   t co zvrfzilyj   https   t co yfard0a',
#  'rt  kennethcfilson  a ripple in the darkness by kenneth c  filson   kindleunlimited  horror  revenge   camping      witch            ghost    love    ',
#  'check out kapiva wheatgrass juice 1l   ayurvedic juice for detoxification   high chlorophyll  th day harvested whe   https   t co 1npeddfym',
#  'gothic halloween prop sewer rat attack floor wall grabber window door decorat    https   t co jrqaunqefm via  amazon https   t co skpbjvvz',
#  ' designationsix  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos   https   t co xadohzqx',
#  ' kailunr  from01to0  medicalbrunette  jesusrodriguezb  amazon no they  re not  https   t co ikrxlbe',
#  ' xboxones 1tb all digital edition console  disc free gaming    discontinued by microsoft https   t co nzfyefalp via  amazon',
#  'rt  orarlington  dear acb members   kcristol  cdarlington  libbygarvey  mattarlington   arlington corporate resident  amazon  has deep ti  ',
#  'check out asus vivobook x11qa ek001t amd quad core a1 0p 1 inch fhd thin and light laptop  gb ram 1tb hdd wi   https   t co vjbyz1oh',
#  'i take my son to  bnbuzz to play with the train set  usually  while we are there  we buy a few books  if not were t   https   t co fucugkljd',
#  'rt  edwardthardy  if  amazon truly believes that  blacklivesmatter  why is it still advertising on breitbart ',
#  ' from01to0  jacksimpson1  medicalbrunette  jesusrodriguezb  amazon like the person said  different sellers  shi   https   t co rsgtvgz',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'realistic zombie temporary fake tattoos walking dead horror costume pierced s    https   t co aolvtfsiy via  amazon https   t co yhiayusj',
#  ' sony  100  playstation store gift card  digital code  by playstation for  100 00 https   t co dzbeyjo11r via  amazon',
#  'rt  soulcages  you should publicly cut ties w   mykastauffer  you supported her special needs adoption  amp  then rehoming him like dirt   am  ',
#  'rt  maryannwrites   a riveting  heart wrenching tale    stars for evelyn evolving  a novel of real life  amp  it s in the top ten best seller  ',
#  ' amazon meet kent  he hits numerous amounts of dingers  he never bunts  and gets his massive power by eating cheese   https   t co xxmmchbw',
#  'rt  warpedinglory  a thread of how vishv books  ghaziabad  up  is carrying and spreading an anti  hindu sentiment through its books  1  i o  ',
#  'did you already check out this amazon deal  samsung galaxy a1 factory unlocked cell phone   1gb of storage   lon   https   t co pabzxlg0',
#  ' sony  playstation  slim 1tb console   only on playstation bundle by playstation for   0 https   t co xcgqmyhyzj via  amazon',
#  ' amazon  amazonin  amitagarwal  jeffbezos  delhivery  please change your  courier partner or they will eat your cus   https   t co luomilbvku',
#  'as it turns out  the only thing worse than the fraud prevention team  amazon is the  amazonhelp customer service te   https   t co yocaqgads',
#  ' clouseaufpl  vbmlwilson  divefpl  renegadesfpl  fpluncorked  mofplmoproblems  fchieftan  thefantasyking   https   t co 0yxlfiwyfg',
#  'rt  krokdrib   0texans  marirruiz  gregmusselwhit  usmcmil0  dallasneedslung  amazon  pepsi  ultabeauty  maccosmetics  netflix we re l  ',
#  'cancelled my  amazon prime account today because i ll no longer support a company that shamelessly exploits human   https   t co hrfuhcmcg',
#  ' from01to0  medicalbrunette  jesusrodriguezb  amazon amazon doesnt set the prices  their sellers do   actually m   https   t co praijunk',
#  ' vrtester  nickhodge  itrollallcapsbr  mylesmill  allcapsbro  nbcnewyork  rabbiassembly  lubavitch  chabad   https   t co otqpeevqek',
#  'rt  1hariprakash1   amazon  jeffbezos black lives matter is not for black lives  it s an anti american anti capitalist org  it never spea  ',
#  '1 https   t co bbkujemhv   https   t co nkaqlvvbiw     amazon  prime video   newest arrivals https   t co oefgihsh',
#  'horror hall funny wine glass goblet naughty nice list christmas party bar hol    https   t co pfgtph1pk via  amazon https   t co ciebdn1gmg',
#  'fishing confetti set  naturecuts  confetti  cutout  partysupplies  favors  decoration  party  event  birthday   https   t co eedhzhjrd',
#  'sleepy sex in a dental chair  the dentist  sedation https   t co xvsbcmlkco via  amazon',
#  'rt  from01to0   medicalbrunette  jesusrodriguezb sent this to  amazon  days ago and haven t gotten a response https   t co eiowbphc1',
#  'rt  abhijee0   amazon  amazonin   amazonhelp  so at the end  after 0 days long wating your orgination was unable to deliver my pord  ',
#  'rt  ratansharda    amazon  amazonin must ban this vendor permanently  how dare a vendor play with  hindu sentiments  isn t freedom to spr  ',
#  ' amazon i support kent because he is an  lfc supporter               https   t co duiohseka',
#  'paperback only on amazon  ebook on smashwords  amp  b amp n  slaves  amp  breeders by j  d  grayson https   t co mrojrjcw via   https   t co jrwwmxywst',
#  'about to blow a gasket in the  amazon customer service chat  don  t eeeeever buy from second party sellers  amazon will be zero to no help   ',
#  'rt  marirruiz   usmcmil0  dallasneedslung  amazon  pepsi  ultabeauty  maccosmetics  netflix  etc please enlighten us  about your choice  ',
#  'check out neuherbs green coffee beans powder for weight loss  00 g   pack of   by neuherbs   https   t co ziezbyre',
#  'rt  juddlegum  1  major corporations publicly embracing black lives matter    including  citi   google  and  amazon    have given hundreds of  ',
#  'rt  shellykramer     slackhq and  amazon announced a big integration late last week  as part of the deal  slack will use amazon chime for i  ',
#  'the doctor s wife becomes a medical textbook  medical school  the patient wife by j d  grayson https   t co utxlclz1a   via  amazon',
#  'spooky horror prop ghostly spirits border scene setter trim halloween decorat    https   t co jqapyyg0le via  amazon https   t co 1mjxinbhk',
#  'rt  nelpnews    amazon s ties w  police enable surveillance of black  brown  muslim communities  amazon tech also powers ice  s detention ma  ',
#  'rt  cmbowenauthor  are you ready to curl up with a thrilling mystery  tap the link below to read   the long road home by carolyn m  bowen f  ',
#  'rt  backtheleos   sign the petition to let  amazon  amp   jeffbezos they are supporting  hatespeech  apparently only towards  lawenforcement th  ',
#  ' vrtester  nickhodge  itrollallcapsbr  mylesmill  allcapsbro  nbcnewyork  rabbiassembly  lubavitch  chabad   https   t co u1njfuj',
#  'rt  worldmusic  new single release  be you  by  worldmusic   applemusic  https   t co zmrddkkc   spotify  https   t co obsecmayc   ama  ',
#  'african americans and africa  a new history by nemata amelia ibitayo blyden https   t co eekrnbedt via  amazon',
#  ' amazon  amazonhelp someone needs to have an answer for me this is the second time i have been charged for prime video ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  ' amazon  defundbezos  buy from small businesses ',
#  'rt  techbreakfast  shout out to christopher walken for joining us today to talk    lilium  evtol startup  mit puts brain synapses on a chi  ',
#  'rt  jumpshotmovie  check out our 10 10 review  incredible  tell you friends to find us on  appletv or  amazon    https   t co hechbjausq',
#  'rt  atlintlaffairs  don t forget  register today for our international ecommerce webinar  amp  hear from industry experts  dr  evaristo doria o  ',
#  'rt  ascendtechllc  support your  remoteworkforce and maintain  security  get a quick  easy and low cost implementation of  amazon  workspac  ',
#  'amazonsmile is now available in the  amazon shopping app on ios and android mobile phones  go to  settings   and sel   https   t co kkpwgbkc',
#  'rt  lauriebarron1   daveschaefer1 angel and the rising star by l s  barron https   t co aycltewrcb via   amazon  mg book  but fun for adu  ',
#  'shout out to christopher walken for joining us today to talk    lilium  evtol startup  mit puts brain synapses on a   https   t co qda1jl0dfp',
#  'rt  lindsayromantic   romance  paperback  feelgoodfiction a summer bewitchment  the knight and the witch  by lindsay townsend https   t co   ',
#  'rt  nelpnews    amazon s ties w  police enable surveillance of black  brown  muslim communities  amazon tech also powers ice  s detention ma  ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'starts at  hours 0 minutes  cc   petefussey  fuzd  jonathanturley  benedictdel  cdeiuk  ajlunited   https   t co xtopcuuyf',
#  'rt  fizapathan  the love that dare not speak its name  short stories by fiza pathan  fizapathan  pridemonth00  lgbtquarenteners  lgbtqia  ',
#  'rt  jerieblack   amazon long time customer asking you to look over the t shirts and messages on your website      black lives matter blue l  ',
#  ' amazon   we re prioritizing orders that are important    except our  prime  items aren t arriving for at least a w   https   t co zcxiweiz',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'rt  jbdarroch  hypnotic redemption now available on  amazon  free for  kindleunlimited   horror  paranormal  supernatural   thriller  myste  ',
#  'fishing confetti set  naturecuts  confetti  cutout  partysupplies  favors  decoration  party  event  birthday   https   t co fpkxxwdtj',
#  'murderous intentions by carol  h  dornetto   https   t co yeb1xwhdf   via  amazon  caroldornetto  crimethriller   https   t co auc1wictmn',
#  'rt  nelpnews    amazon s ties w  police enable surveillance of black  brown  muslim communities  amazon tech also powers ice  s detention ma  ',
#  'rt  nelpnews    amazon s ties w  police enable surveillance of black  brown  muslim communities  amazon tech also powers ice  s detention ma  ',
#  ' daveschaefer1 angel and the rising star by l s  barron https   t co aycltewrcb via   amazon  mg book  but fun for   https   t co tkpmbbxi1e',
#  'not  crypto related   although they do take crypto donations  eeveryone should turn this on   it costs nothing    https   t co clvztnmuu',
#  ' amazonhelp  amazon  amazonin  amitagarwal  delhivery  jeffbezos what a lei    and what kind of weed  amazon and   https   t co gkvzlvbpj',
#  'check out hp 1 di0001tu 1  inch laptop  pentium gold 1u gb 1tb windows 10  home integrated graphics   jet bl   https   t co vauxcihff',
#  'check out this amazon deal  samsung galaxy a1 factory unlocked cell phone   1gb of storage   long lasting batter   https   t co uqyurbj',
#  'rt  fizapathan  the love that dare not speak its name  short stories by fiza pathan  fizapathan  pridemonth00  lgbtquarenteners  lgbtqia  ',
#  ' amazon are you seriously selling shirts that say blue lives murder   you said u have no control and can  t remove    https   t co qvvkatavae',
#  'rt  scampbell11  just saw this on amazon  all out war  the plot to destroy trump by klein  edward for  1  https   t co xccyhmer vi  ',
#  'check out wellbeing nutrition grandma s kadha  organic certified ayurvedic herbal remedy for cold  cough  flu  sore   https   t co ihsdphejh',
#  ' from01to0  jacksimpson1  medicalbrunette  jesusrodriguezb  amazon that  s not how that works  amazon fulfills t   https   t co molzsb',
#  ' amazon uk i don  t know how i can raise a return when i  m stuck in the house shielding due to medical conditions so can  t go to post office',
#  'gothic skull dead end fright caution tape halloween party decoration prop 0f    https   t co giebwqflgj via  amazon https   t co huwieyk',
#  ' amazon  amazonhelp how do i return an item that i ordered on  1  it arrived    tried to cancel in april  never   https   t co cp1ztvy',
#  'what is it with  beallsoutlet that is trying to drive customers to  amazon and themselves out of business  bealls   https   t co ryprwczsi',
#  'rt  aclu  your turn   amazon and  microsoft ',
#  'life size body part severed bloody zombie foot creepy haunted house horror pr    https   t co tj0afpeggj via  amazon https   t co ihchitlv',
#  ' amazon prime video was where i went to escape the   news cycle  i was one of your best customers  i cancelled    https   t co gfazxytsj',
#  ' daveschaefer1 harper t and the timewave by l s  barron https   t co mozbwswn1 via   amazon   books in this seri   https   t co bbggagnou',
#  'rt  from01to0   medicalbrunette  jesusrodriguezb sent this to  amazon  days ago and haven t gotten a response https   t co eiowbphc1',
#  'haunted house prop bloody caution zombies warning sign fright tape decoration    https   t co fjxnbzgbc via  amazon https   t co xlmawmhxn',
#  'racism  where is your sting   a provocative look at the beginning and the end    https   t co 1hxhuvmpa via  amazon',
#  '1in confetti set  fish cut outs  naturecuts  confetti  cutout  partysupplies  favors  decoration  party  event   https   t co caragi',
#  'rt  thedsc   ananavarro all of these brands need to pull ads from racist fox news if they really support  blacklivesmatter  amazon  krafthe  ',
#  'gothic novelty skull crossbones ice cube tray jello mold pirate birthday part    https   t co ibwcbwwy via  amazon https   t co ytw11yrzph',
#  'abilene  the bondage of suyin wong by christopher zisi  cjzisi a love story transcending time  morals and worldly j   https   t co amoanvs',
#  'as good as dead   a classic western adventure  a fort smith western tale by lowry  chris   https   t co jtigaw1mc   https   t co qrcdvlxul',
#  'rt  nyliterary  happy pub day  authorsarahs for if you never come back    amazon  https   t co jflnzcmmae',
#  'apple watch series     mm space grey aluminum case with black sport band a    https   t co mqqwkspqs via  amazon https   t co v0mzvfltvl',
#  'rt  marilynbrant  the knight before christmas is out now      i am rarely spellbound by romance alone but this book drew me in from the beg  ',
#  'wacky turkeys peel  n place   leaves included  party accessory   1 count       https   t co mw1loczzy via  amazon https   t co nivdpszoz',
#  ' rgriercpa  jeffbezos  amazon  washingtonpost      humor aside    jeff bozo is a tyrant   boycott   close your accou   https   t co ffxlqfp0xm',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  ' amazon  amazonhelp dear amazon  your prime delivery folks are not wearing any gloves or masks   is that normal   i   https   t co kgivu1uh',
#  'seriously   amazon  this is the third time i  ve raised this issue  you keep saying you  re working on it  how long d   https   t co dcjcwdctww',
#  '  amazon s ties w  police enable surveillance of black  brown  muslim communities  amazon tech also powers ice  s de   https   t co qdazzkvqa',
#  'now even  amazon is supporting the blm terrorist   boycottamazon   liberalismisamentaldisorder',
#  'rt  stevens0   insaneclownprez  justinbaragona  acyn brought to you by   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pill  ',
#  'funny zombie crossing fright caution warning tape halloween prop decoration     https   t co el1cdyvd via  amazon https   t co cibgcmdwl',
#  ' kcristol  libbygarvey  cdarlington  mattarlington   it should be added that  amazon was also firing black wareho   https   t co odhyvwalev',
#  ' amazonhelp  amazon still pickup is pending  what a underrated team you guys are  u people cannot schedule a simple   https   t co 1slkxwnfiz',
#  'if we as a community put pressure on  amazon and  awscloud  maybe we can get them to   amazonrekognition https   t co xeswcifhp',
#  ' amazon  amazonca why can t you refund customer money on time  you deducted money while processing order and delive   https   t co olyl0efa1',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'rt  sandrayearman  brother kings    the warrior series   vol 1    by sandra j yearman https   t co jzwip01hqw    via  amazon  series  fantas  ',
#  'zombie inside door keep away turn back  cover walking dead horror prop decora    https   t co brjhob via  amazon https   t co bjysgiivff',
#  ' backtheleos  amazon  jeffbezos  bluelivesmtr  bluealertus  nationalsheriff  natpoliceassoc  policefound   https   t co haxrnxhiy',
#  'rt  lisajewelluk  the family upstairs is today s kindle daily deal  available now for only p    for one day only     thefamilyupstairs  a  ',
#  ' crazycliff  twitch  amazon  pretzelrocks the thing is that it was music from a guy called lakeyinspired  and he charges no royalty',
#  ' timboone  kitchetech  aalexis1  isforat  amazon in my experience in il  it can be enforceable if there  s    at   https   t co moavpgxj',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'how do i provide them with information that i do not have    why would i ever want two  amazon prime subscriptions ',
#  'the  amazon folks say that i have another email account attached to my cc that is subscribed to amazon prime    i v   https   t co romg0zrjut',
#  'featured chromebooks  amazon  deals  onlineshopping  ad  computers https   t co yail0sbebs',
#  ' amazon  you have some explaining to do      why would you  allow the seller to sell those masks        https   t co yofxyhgcp',
#  'rt  iheartmindy  dear ebay and amazon  please add an option that filters out all the cheap crap from china and add a feature that would all  ',
#  'every company right now  facebook  amazon  pepsi  twitter  google  apple https   t co nweosukxw',
#  ' bts  galaxyzflip  samsunggalaxy  galaxy  galaxys0  galaxys0series  v  bestofme  samsung  check out samsung galax   https   t co lwx1ie0ti',
#  'https   t co mrdccd0ncr   jennifer gentle musica https   t co hlv0cyu via  amazon',
#  'rt  gametogrow  if you are making purchases through  amazon  you can now use the app to make purchases with amazon smile and provide extra  ',
#  ' ambrishbajaj  amazon  microsoft  facebook  apple  google of course google',
#  ' twitch   amazon  y  all need to make merchandise and clothing for people bigger the xl just says',
#  '1in confetti set  bobber cut outs  naturecuts  confetti  cutout  partysupplies  decoration  party  event  birthday   https   t co ufcqmcdhxg',
#  ' kconnect  a raleigh  nc based technology company  and  amazon are partnering to distribute more than  000 echo d   https   t co mpwlxpqc',
#  ' amazonhelp here too it s the same reply  this i know that either i can return it  but i want to use it  just want   https   t co xikqh1d',
#  'let  s see  toughguy  jeffbezos fire his armed security   amazon  washingtonpost https   t co lykggmxrad',
#  ' wklawrence  amazon  amazonbooks done  https   t co zwbahpsu',
#  ' amazon  amazonhelp  need immediate help and need to return the item  amazon is best known for their customer servi   https   t co pnhhtfis',
#  ' from01to0  medicalbrunette  jesusrodriguezb  amazon well i  m trying to understand why the  dolls would be pric   https   t co nbtapui0hu',
#  'rt  jakedockter    amazon says they stand for black lives    they also host books and  primevideo content for douglas wilson    lets look a  ',
#  'rt  btsbighit  don t forget to pre order a copy of map of the soul    at  amazon today  https   t co yzwxrpcf',
#  'rt  from01to0   medicalbrunette  jesusrodriguezb sent this to  amazon  days ago and haven t gotten a response https   t co eiowbphc1',
#  'rt  sasantosauthor  sacrifice by s  a  santos https   t co feqlqlecr   via  amazon it took weeks for jason to finally find kat and free her  ',
#  '100 tiny miniature gold screw eye upeye eyepin dollhouse crafts gp brass  x     https   t co moyvyzvqo via  amazon https   t co ehombcehz1',
#  ' jacksimpson1  medicalbrunette  jesusrodriguezb  amazon wrong  if i return it or have any issue  it goes through a   https   t co vzmwqygfnm',
#  'the eagle has landed on st colmcille  s day  johnkellytweets via  amazon how about that for a cover quote from the f   https   t co jjpaywmvpv',
#  'apocalyptic apothecary  left with nothing but roots and herbs  time is running out https   t co yg1pcqyqf via   https   t co cypecmphuh',
#  ' backtheleos  amazon  jeffbezos  bluelivesmtr  bluealertus  nationalsheriff  natpoliceassoc  policefound   https   t co zehonourh',
#  ' zeagoo  amazon  one of your sellers  refuses to refund a purchase i made on 1 april 00  yet have not receive   https   t co w1spsvmqm',
#  'rt  iamshunaji  support the cause  i started a spreadsheet as a directory for small and medium enterprises and cooperatives so we can dives  ',
#  ' amazon customer service over the chat sucks    the thing the rep told me wouldnt happen is exactly what happened    https   t co loxxj1nxy',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'when you get an update on an  amazon order saying it s 10 stops away let the countdown begin   ',
#  'battlefield z mardi gras zombie a post apocalyptic sci fi adventure by lowry  chris   https   t co hwtwehjb via   https   t co smdnoqit0y',
#  ' theweleadership  sportsiren  amazonsmile  amazon  mariataylor  twilkz  wbaggs  coachjulieshaw  ronikastonee   https   t co qzifsog1',
#  ' amazon i support a union and dignity on the job for amazon workers  that s how you care for families ',
#  'i just listed  soft baby rag dolls 1 1 inch red hearts stuffed starters plush snuggle buddy cuddly body play toy    https   t co qxsnxeuyaw',
#  ' crashdev  isforat  amazon indeed  i might ad that this is a rather prevalent practice in the tech world ',
#  ' amazon  amazonhelp  this is not just done  i brought this item with the only positive hope that i can return it if   https   t co dnz1nrfev',
#  'i just listed  awake and asleep dolls purple pink soft baby doll stuffed starters snuggle buddy cuddly body play to   https   t co mzutejhmm0',
#  ' busiswagibson  ginaasada  amazon thank you ordered   i cannot wait ',
#  'an coffee bean   vietnamese iced coffee   extra bold   air roasted coffee   single serving packets    amazon  https   t co 0isowko',
#  'rt  busiswagibson   sussexsquad don  t forget to pre order your book from  amazon   we need to make this book a bestseller   https   t co ea  ',
#  'looking for kobe bryant fan items   click here https   t co hfidsi0e via  amazon  kobebryant  lakers  basketball',
#  'battlefield z   children s brigade  a post apocalyptic sci fi adventure by lowry  chris for      https   t co ijerarilr',
#  ' brockgoldstein  medicalbrunette  jesusrodriguezb  amazon nope  there are more  this is just the screenshot i took   https   t co hvqardoyk',
#  ' vrtester  nickhodge  itrollallcapsbr  mylesmill  allcapsbro  nbcnewyork  rabbiassembly  lubavitch  chabad   https   t co wcdkprqzc',
#  'rt  crashdev  there are much more fundamental injustices being fought for right now  but depressed to see  amazon continuing to use  noncom  ',
#  'rt  from01to0   medicalbrunette  jesusrodriguezb sent this to  amazon  days ago and haven t gotten a response https   t co eiowbphc1',
#  'rt  fdsnaturallyme  a group of college friends who try to challenge their identity ends up fighting against mythical elements  teleporting  ',
#  ' amazon  your team is saying that i will not get any refund   it means your deliveryman is right and i am wrong    https   t co dedzntjatf',
#  'rt  theweleadership  did you know  amazonsmile is now available in the amazon shopping app on ios and android mobile phones    your  amazon  ',
#  'fish cut outs  hook cut outs  naturecuts  confetti  cutout  partysupplies  favors  decoration  party  event   https   t co n11rt0sqp',
#  'vosha and fashye through the star seas  the source by thomas ransdell https   t co smnuxfa via  amazon',
#  ' amazon what happen to the   hazardous pay   i still have to wear mask at work and remain ft from my coworkers  a   https   t co waxfygh',
#  'rt  theweleadership  did you know  amazonsmile is now available in the amazon shopping app on ios and android mobile phones    your  amazon  ',
#  '  in 1 hr we have a live chat with former  amazon group product manager on our  slack channel   join here   https   t co rxmhapggj',
#  ' big book of rejections  kindle edition  have you ever wondered if that rejection letter you got from an agent or p   https   t co tob1yatgp',
#  'rt  designationsix  please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  ',
#  'rt  miamiherald  miami beach is getting its very own  amazon  star store  only one of three locations in florida  https   t co edcm1sevth',
#  ' designationsix  socallls  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos   https   t co hdsfpnq01',
#  ' amazonhelp  amazon  zeagoo  one of your sellers  refuses to refund a purchase i made on 1 april 00  yet have no   https   t co ywegkjvlb',
#  ' amazon  zeagoo  one of your sellers  refuses to refund a purchase i made on 1 april 00  yet have not received a   https   t co kt1gbhoh1p',
#  'so i ordered a blackhead vacuum from  amazon and i thought that it would be just another fluke but when i tell you   https   t co uptrtamrw',
#  'rt  theweleadership  did you know  amazonsmile is now available in the amazon shopping app on ios and android mobile phones    your  amazon  ',
#  'battlefield z zombie blues highway a post apocalyptic sci fi adventure by lowry  chris   https   t co sgyqhrdwi vi   https   t co pyizdmcu',
#  ' amazon we can understand that this covid has affected everyone   but did not expect you ppl also to behave this wa   https   t co uyvwbkzpnc',
#  ' amazon what the hell  this is how you wrap a glass item   luckily i didn  t cut my hand and no way in hell am i ris   https   t co zldmjeqsh',
#  ' sigmajump  xseedgames  digitalemelas im sad  amazon doesnt have a ship date till the 1th  what gives  amazon  ',
#  ' alshark  amazon i know you meant  jeffbezos  but it  s worded to make it sound like i  m gonna be worth  00b so i  m   https   t co lequcstf',
#  'rt  theweleadership  did you know  amazonsmile is now available in the amazon shopping app on ios and android mobile phones    your  amazon  ',
#  ' backtheleos  amazon i raely buy from amazon  only if absolutely necessary   as they allowed an author who was a r   https   t co i0pasrqrg',
#  'i thought you didn  t need the contracts     amazon sues former aws marketing vp brian hall after he takes google cl   https   t co tobhhxng0h',
#  'apple airpods with charging case  latest model    white apple https   t co znqzibxb via  amazon https   t co abqnznz0',
#  'isis  the main event by shawn james https   t co lonbgzllw via  amazon',
#  'novelty spider   web ice tray mold halloween jello shot birthday party spider    https   t co bsqdzlm via  amazon https   t co avxtokzuw',
#  'among the large tech players  amazon   microsoft   facebook    apple  amp   google  who would be the covid winners     w   https   t co 0nfzmuhe',
#  'rt  lindsayromantic  voices in the dark by lindsay townsend https   t co svmhhgpuy via  amazon  romanticsuspense  italy  cents',
#  'rt  jediknight11   amazonhelp  amazon please tell me all of a sudden it is not possible to follow the simple instructions as to where to  ',
#  'saving daddy s privates  a sex shop series novella by olivia marie https   t co tlkmwjdh1b via  amazon',
#  'there are only  black owned bookstores in ma   frugalbookstore and  olivetreebooks  i m no longer purchasing any   https   t co luhnawyi',
#  ' jasalexandra  amazon omg      amazon was feeling petty lol',
#  ' rosyrosay  toapod  amazon great question  they are not necessarily the same  cbd does come from the hemp plant  b   https   t co muprkjookl',
#  'rt  nessa011   designationsix  leshailyes  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos  unive  ',
#  'rt  coasterinoregon   takeadive  doggintrump  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos  unive  ',
#  'rt  takeadive   doggintrump please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  ',
#  'rt  fenrir1   designationsix  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos  universalpics  nestle  ',
#  'horror hall walking dead zombie visitors door cover wall mural haunted house     https   t co roml01vux via  amazon https   t co rtkgbcpr',
#  '  amazon will you support black communities by stopping the sale of facial recognition technologies to police force   https   t co mnzjrsh',
#  'rt  muchodonchatz  star  psycho  werewolf  horror  novel with all new  coverart for  kindle   illustrated   https   t co fummzbs1y',
#  ' amazon these types incident shows loose interest in business  https   t co vrsdokocyk',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'rt  jamnspoon   designationsix  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos  universalpics  nestl  ',
#  ' designationsix  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos   https   t co aaj10h',
#  ' from01to0  medicalbrunette  jesusrodriguezb  amazon perhaps due to there being  only 1 left  ',
#  'check out alpino thar gt over ear bluetooth headphones   hd bass  amp  noise cancellation   bluetooth  0  amp  long batter   https   t co nogo0okzl',
#  ' ssatyam01  flipkartsupport  amazon any update busy people as if you guys are the busiest in this world ',
#  'large heavy duty clear backpack   see through transparent bookbags for school    https   t co bqkdhmn0vw via  amazon',
#  'rt  from01to0   medicalbrunette  jesusrodriguezb sent this to  amazon  days ago and haven t gotten a response https   t co eiowbphc1',
#  'salmon fish cut outs  hook  naturecuts  confetti  cutout  favors  decoration  party  event  birthday  wedding   https   t co dsvzgvqx',
#  'screaming for pleasure  how horror makes you happy and healthy  sponsored  amazon  benefitsofhorror  writing https   t co pizotpuvv',
#  '  x  degree pvc white schedule 0 street elbow spigot x socket 0 spears https   t co rq0vovhph via  amazon https   t co fwclu1fv',
#  'overland zombie   a post apocalyptic thriller  battlefield z series by lowry  chris for      https   t co mslcbeyyx',
#  'writing research papers  the essential tools  student book only   ifyouneedthis  writingtips  amazon https   t co cfqwrfp1',
#  'haunted house morgue bloody creepy cloth halloween prop table door decoration    https   t co bpaqyxfhz via  amazon https   t co yzygkfqrt',
#  ' hpierrejacques  amazon their whole delivery model is not electronic  they  re logistics is still paper driven for the air freight ',
#  'if you are an  amazon   amazonprimenow   shopper let your  generous spirit show via  amazonsmile and support   https   t co pvpt0xs1n',
#  'sheer morph scary leprechaun elf mask frankenstein monster cosplay costume gr    https   t co yagwbemvo via  amazon https   t co djqmjbjvq',
#  'rt  beingfucking   from01to0  medicalbrunette  jesusrodriguezb  amazon you don t really think amazon makes barbie dolls do you  have you  ',
#  'rt  jamnspoon   designationsix  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos  universalpics  nestl  ',
#  'rt  mommabear11  so all protestors don t want  b lumped in with the rioters  all black people don t want  b lumped in with gangbangers   ',
#  ' amazon kent going to buy his son a blue lived murder shirt that amazon is now offering  ',
#  'rt  designationsix  please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  ',
#  'just saw this on amazon  boppy original newborn lounger  elephant love gray by boppy for      https   t co fqtitvmp',
#  'rt  sierracool   beingfucking  from01to0  medicalbrunette  jesusrodriguezb  amazon i think you missed the point',
#  'rt  designationsix  please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  ',
#  'check out this amazon deal  proactiv solution  step pro acne treatment system  0 day original acne kit  by proact   https   t co tvdbizunh',
#  ' kailunr  medicalbrunette  jesusrodriguezb  amazon yes  amazon  and both are prime items  either way  just as   https   t co 0odttpwko',
#  'funky black gray zebra stripe knee socks animal print lolita soccer volleybal    https   t co kyakjugri via  amazon https   t co ncvcgpk',
#  'walks with him  comanche bride  native brides book 1  by elle marlow https   t co cwwhjxlt via  amazon    have yo   https   t co mjapdifd',
#  'rt  lindsayromantic  voices in the dark by lindsay townsend https   t co svmhhgpuy via  amazon  romanticsuspense  italy  cents',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'check out design elle wooden couple personalised led lamp with any alphabet and lamps  brown  1x inches  by desig   https   t co ktnafysds',
#  ' designationsix  jamnspoon  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos   https   t co tsvmvt0eyl',
#  ' jphoniks  jeffbezos  amazonpolicy  amazon  jaycarney  davehclark jeff bozo is a tyrant   boycott   close your acc   https   t co kadgkbopgp',
#  'rt  weaveinfluence  are you interested in learning how to  engage young professionals in your organization   preorder a copy of  nathanmagn  ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'rt  armandauthor  beers and fears  flight night  https   t co ieslkojoh    amazon  armandauthor  timmmeyer11  cebuda  njmetal  horror  ant  ',
#  ' drinkspindrift might want to reconsider their packaging choices  as  amazon is not careful when packing and shippi   https   t co ngaajzhqg',
#  'rt  dangeiger    amazon continues adding to its huge footprint of warehouse space in and around nyc  taking 00k s f warehouse in south b  ',
#  ' seriousbismuth  imdatagirl  sleeppatternav  augnosmusic  twitch  amazon twitch as a platform works very well for   https   t co nwnsbzwzm',
#  'halloween creepy spooky scary haunted house witches  cauldron wall mural hall    https   t co dohpehkn via  amazon https   t co sii1dgz',
#  ' amazon i would like to return a package  i received the wrong watch from the seller  when i tried to contact custo   https   t co lj1xbjgoz',
#  'dear  amazon y all trash',
#  'battlefield z outcast zombie by lowry  chris  https   t co 0xgcit0hef via  amazon    kindleunlimited  scifibooks',
#  'rt  designationsix  please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  ',
#  'rt  thedsc  here s an updated list of advertisers that used  blacklivesmatter to promote their brands while currently advertising on racist  ',
#  'rt  urocklive1   designationsix  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos  universalpics  nestl  ',
#  'rt  designationsix  please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  ',
#  ' pcs skeleton arm body parts bloody horror hand lawn stakes set prop decorat    https   t co jxbxhrit1 via  amazon https   t co vxpgwqai',
#  ' designationsix  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  audiblecom  zappos   https   t co txuhqfhxbi',
#  'ones and zeros are only good for coding not for describing how many black people work on your executive leadership   https   t co gbwrhwp',
#  'rt  designationsix  please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack  ',
#  'rt  kzhowell  a new  review  an excellent sf read   simply put  this is a great read for those who enjoy science fiction  howell makes t  ',
#  'check out glimmer lightings copper quirky photo clip string lights with wooden clips  0 bulb   m  warm white  by   https   t co jiyplocat',
#  ' sparks10 we  re going to war with you watch your back  amazon',
#  'haunted house blood monster zombie ghoul toilet cover halloween party decorat    https   t co bnsgosmbys via  amazon https   t co uxrhfwckj',
#  ' amazon should consider re training their crew that approves customer reviews  lately  it feels like half the revie   https   t co opqn0cwthf',
#  'rt  stevens0   insaneclownprez  justinbaragona  acyn brought to you by   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pill  ',
#  ' imdatagirl  forgottenvcr  sleeppatternav  augnosmusic  twitch  amazon yeah let me say that i m definitely not her   https   t co ehpgoir',
#  'rt  mfdubravcic  you can read my book and be happy ever after   paulie and the scary scream  dreamy eyed kids  by monika flegar dubravi  h  ',
#  'rt  reasjack   docsaico  hbomax  amazon in my perfect world  every girl born gets their own copy of kiki s delivery service ',
#  'bluegill fish cut outs  naturecuts  confetti  cutout  partysupplies  favors  decoration  party  event  birthday   https   t co uge1zbsm',
#  'rt  1hariprakash1   amazon  jeffbezos black lives matter is not for black lives  it s an anti american anti capitalist org  it never spea  ',
#  ' amazon  amazonin   amazonhelp  so at the end  after 0 days long wating your orgination was unable to deliver my p   https   t co spnnkdh',
#  'https   t co mrdccd0ncr   illogicist musica https   t co bmdaakd1 via  amazon',
#  ' amazon way to go delivering my packages on days i was not at the house when i chose to deliver on a different day   https   t co puxmruttz',
#  '100 tiny miniature silver plate screw eyes upeyes eyepin eye peg crafts  x     https   t co gwpwcbepvg via  amazon https   t co fnskhndu',
# ...
#  'check out this amazon deal  champion men s jersey short with pockets  navy  small by champion https   t co xs1lor1ztj via  amazon',
#  ' thakuranurag0  shieldvoc  amazonhelp  amazonin  amazon  jeffbezos  flipkart i hope you don t mind me chiming in    https   t co opwqkkzea',
#  'just saw this on amazon  carhartt men s k workwear short sleeve t shirt  regular and big  amp  tall sizes   black  sm   https   t co ydkclmqo',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'rt  mfdubravcic   thekaibeck  kevinbarrick you just have to read it  a little book about a boy and his parents  fun  imaginative  and witty  ',
#  'i just listed   unique loom richmond collection medallion overdyed oriental transitional       for   via   https   t co xtydiutdw',
#  ' amazonhelp  audiblecom am still waiting for support or help  amazon',
#  'rt  thedsc   ananavarro all of these brands need to pull ads from racist fox news if they really support  blacklivesmatter  amazon  krafthe  ',
#  'rt  takeadive   doggintrump please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  amazon  ring  ',
#  'check out this amazon deal  white fragility  why it s so hard for white people to talk about racism by dyson  micha   https   t co i0sixnwsv',
#  ' amazon one of my shipment with tracking id 00 is showing delivered but not received at given adress',
#  'check out this amazon deal  so you want to talk about race by oluo  ijeoma https   t co jzferixixd via  amazon',
#  'rt  mommabear11  so all protestors don t want  b lumped in with the rioters  all black people don t want  b lumped in with gangbangers   ',
#  ' amazon  amazonhelp amazon has deducted access money from my account   the link amazon generated for the deduction   https   t co qieedvvyy',
#  'rt  aclu  your turn   amazon and  microsoft ',
#  'the police are using facial recognition software from  amazon to arrest people  yes  even in denver ',
#  'rt  aclu  your turn   amazon and  microsoft  https   t co zaucxkllw',
#  'rt  miamiherald  miami beach is getting its very own  amazon  star store  only one of three locations in florida  https   t co edcm1sevth',
#  'it s alive  bringing your nightmares to life  the dream weaver series book    sponsored  amazon https   t co nukrncdasa',
#  ' essential writing tools  that will absolutely make your writing better  and enliven your soul   amazon https   t co ghg1hgq',
#  ' rntata000  tatacompanies  tatacliq  tatacliqcare  consumercourt  amazon  flipkart    boycottatacliq tata brand i   https   t co vehyozwvh',
#  ' juliancastro  ibm  amazon we could also ban this type of technology since we know it s used to racialize and crimi   https   t co azmpkyyy',
#  'keep seeing  pinterest and  amazon messages on their support  does this mean employment programs for returning citizens are on the way   do',
#  'rt  1hariprakash1   amazon  jeffbezos black lives matter is not for black lives  it s an anti american anti capitalist org  it never spea  ',
#  'rt  freepress  don  t be fooled   amazon isn t fighting anti blackness  they give direct  material tech support to 1 0 police depts across  ',
#  'today is the day  be sure to pick up your copy of  mayahuchan s  savingface between 10 am et and  pm et to help ma   https   t co mmgtxjaf',
#  'rt  wyattcenac   athenaforall on  problemareashbo we tried to talk about how  amazon and  facebook were selling their facial recognition so  ',
#  'rt  mnsibley  world got you stressed out   need a calming read   a good  cozy story   something to take your mind off our descent into dyst  ',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'rt  kimmyschemy0  the old guitar and other stories by ks agustin https   t co bqww1lrmxw via  amazon  free on  kindleunlimited',
#  ' yosissynyfl  wigginsmargie  cbsherridge  cbsnews  reebok  nike  nfl  nflcommish  crossfit  amazon  speakerpelosi   https   t co ygnthqmyi',
#  'world got you stressed out   need a calming read   a good  cozy story   something to take your mind off our descent   https   t co mwmgnfzx',
#  ' beckyrbnsn  amazon it looks like the weaving influence website is down fyi  https   t co buzftlap',
#  'rt  aclu  your turn   amazon and  microsoft  https   t co zaucxkllw',
#  'preppers road march  prepper trilogy  book 1  by ron foster https   t co wuicqzyfiu via  amazon  solarstorm  prepper  survivalist',
#  ' noechonet just dropped an exclusive excerpt from the forthcoming the blood and the sweat  the story of sick of it   https   t co wlvomjghe',
#  ' takeadive  stabbytosavit  willapercy  kraftheinzco  mypillowusa  disney  hulu  amazon  ring  pillpack   https   t co kksqstlva',
#  ' healthythinker  amazon  himss  healthpopuli searches like  has this symptom occurred before  has there  been compl   https   t co mfu1v0',
#  'rt  brutiedada  new scam  amazonhelp  amazon please alert your customers  donotclickthelink https   t co ia1ptxjnsd',
#  'th parallels  alternative canadian histories and futures by hayden trenholm https   t co jukn0j via  amazon',
#  'i love to pay it forward especially to the essential workers who work no matter what           usps  ups  fedex   https   t co aibiobcri',
#  'battlefield z complete adventures  a science fiction post apocalyptic comedy collection  volume book 1  by lowry  c   https   t co xryopvw',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  ' lisajewelluk  amazon what i am currently reading  almost finished  such a good read  https   t co wlyaiazj',
#  'rt  kzhowell  an engaging irish historical romance for readers who loved what the wind knows  lady ellen  leap year  and brooklyn  by  jgm  ',
#  'rt  thedsc  here s an updated list of advertisers that used  blacklivesmatter to promote their brands while currently advertising on racist  ',
#  'shop thousands of electronics items at https   t co sujjxxjb  free two day shipping with prime  https   t co lqswcqb via  amazon',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  'shop for laptops  computers   amp  memory from your favourite brands like microsoft surface  chromebook and zenbook  fr   https   t co kfeazwdlfl',
#  ' amazon as an amazon customer this makes me seriously consider no longer doing business with them  i don  t use thei   https   t co ru1tt0sl',
#  'handy for all our zoom meetings  tripod for iphone by linkcool for  1  https   t co 0pol1lz via  amazon  zoom   https   t co qhqdccui',
#  ' joenorte  wigginsmargie  cbsherridge  cbsnews  reebok  nike  nfl  nflcommish  crossfit  amazon and buying seats   https   t co hxetvqx',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'battlefield z zombie blues highway a post apocalyptic sci fi adventure by lowry  chris   https   t co jhmrjiujf via  amazon',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'rt  childmari  return of the maca  chronicles of the maca  book  by mari collier https   t co dhdacgz via  amazon',
#  'samarth w  amazon  amazonjunequiz https   t co trqvqhlrws',
#  'rt  kimmyschemy0  the old guitar and other stories by ks agustin https   t co smhebwhoaq via  amazon  shortstories  flashfiction',
#  ' drhorwitz  amazon  jeffbezos this is disgraceful   ',
#  'rt  amazon  meet oscar  an amazon delivery associate working to support his newborn baby  he takes great pride in delivering packages safel  ',
#  'coming soon  check out brad chase s new book   strategyfirst  how businesses win big  focused on  businessstrategy    https   t co jcq',
#  'coaches rely far too much on asking open ended questions  read more from our client  marciareynolds in her new book   https   t co adzljuq',
#  'battlefield z   children s brigade  a post apocalyptic sci fi adventure by lowry  chris for      https   t co intvhuufu',
#  'the dipole shield  a science fiction action adventure comedy  the dipole series book   by lowry  chris   https   t co k0kjfsro',
#  'samarth w  amazon  lgamazonquiz https   t co h0e0zlvyt',
#  ' beingfucking  from01to0  medicalbrunette  jesusrodriguezb  amazon i think you missed the point',
#  'rt  takeadive   willapercy  stabbytosavit please leave a comment for these sponsors of fox news   kraftheinzco  mypillowusa  disney  hulu  ',
#  'rt  mommabear11  so all protestors don t want  b lumped in with the rioters  all black people don t want  b lumped in with gangbangers   ',
#  'rt  andraydomise  let your workers unionize if you believe it  otherwise  keep it  amazon https   t co kbfpti0hr',
#  'rt  kzhowell  a new  review  an excellent sf read   simply put  this is a great read for those who enjoy science fiction  howell makes t  ',
#  'rt  1hariprakash1   amazon  jeffbezos black lives matter is not for black lives  it s an anti american anti capitalist org  it never spea  ',
#  'rt  brutiedada  new scam  amazonhelp  amazon please alert your customers  donotclickthelink https   t co ia1ptxjnsd',
#  ' amazon soooo no one is answering your phone   wtf    how can i get a hold of someone when i can  t do something via your website ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  ' amazon stop advertising on foxnews   moneytalks',
#  'rt  joshlecash  everyone pls support  amazon   it s a small  black owned business ',
#  'rt  designationsix  fox showed a graph of how good the stock markets do when black people are murdered  mlk  s assassination was on it  here  ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  ' firstnoellem  dhmorrow1  joshinishad  gatewaypundit  amazon she is an idiot and let this happen  less jobs that will be the outcome',
#  ' amazon i am a prime customer and need clarification from amazon   i am not racist  amp  am horrified of what happened   https   t co plvujkbej',
#  'rt  lowrychris  beachhead  invasion earth   https   t co ovljzywru via  amazon    scifi  kindleunlimited  ku  series https   t co ypbpvro  ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'it  s been over a month and i still haven  t received my black out curtains  amazon   ',
#  '   about that  feat  mc one line  shadowstar boxing academy https   t co egobxzqgdf via  amazon',
#  'i saw your statments that  blacklivesmatter but now where is your strategy to change the systematic racism that exi   https   t co xte1uj',
#  'covid has accelerated online video   but the most fertile market ripe for digitization is  india   explains why   https   t co jtwzjmekey',
#  'amazon is opening a store in south beach  https   t co cejcnrkyer vi  timeoutmiami  virginwrites  amazon  jeffbezos   https   t co xzipkz0mf',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'phone tripod  ubeesize portable and adjustable camera stand holder with wireless remote and universal clip  compati   https   t co gnvnpiwto',
#  ' iszpikitv  twitch  amazon  pretzelrocks thats bad  its not safe using suppisdly copyright free playlists on spoti   https   t co k1hxacneqi',
#  'exterior conflix  feat  vinny steez  amp  mc oneline   explicit  portarok https   t co vbsyeysuvf via  amazon',
#  'rt  campcarefree  good news for  amazon shoppers who want to support us   amazonsmile is now activated in the phone app  simply go to setti  ',
#  'rt  mommabear11  so all protestors don t want  b lumped in with the rioters  all black people don t want  b lumped in with gangbangers   ',
#  ' beholdisrael  amazon reading   ',
#  ' juliancastro  ibm  amazon or simply ban face recognition tech  both from private and government use     and it  s ti   https   t co plkpuwybt',
#  'good news for  amazon shoppers who want to support us   amazonsmile is now activated in the phone app  simply go to   https   t co nxypykrpy',
#  'blade artifacts  feat  rez sps kings  mc oneline  amp  caper   explicit  portarok https   t co uyvxvrwt via  amazon',
#  'rt  backtheleos   sign the petition to let  amazon  amp   jeffbezos they are supporting  hatespeech  apparently only towards  lawenforcement th  ',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  '10  selfie ring light with 0  extendable tripod stand  amp  flexible phone holder for live stream makeup  ubeesize min   https   t co mumhrwtbra',
#  'rt  1hariprakash1   amazon  jeffbezos black lives matter is not for black lives  it s an anti american anti capitalist org  it never spea  ',
#  ' dimpygulati1  gcbcoalition  billgates  satyanadella  sundarpichai  elonmusk  timcook  jeffbezos  amazonpolicy   https   t co uebmgfwcbg',
#  ' michell  pbs  masterpiecepbs  wgbh  sanditon  primevideo  amazonstudios  primevideouk  amazon i know      https   t co fzbfkyxn',
#  'asian chambers  feat  mc oneline   explicit  royalty bourne https   t co zshhkysxi via  amazon',
#  'checkout amp   anthology  all  books in 1 volume  be on the lookout for amp audio in a very short time    https   t co olkotit',
#  '  ufcise  s my t  thai  associate director of the  nelmsinstitute  amp   uf foundation professor  received a   year aw   https   t co hdguflse',
#  'rt  athenaforall  while we protest they record  so while  amazon launches  blacklivesmatter promotionals and  jaycarney takes performative  ',
#  ' leojleon start with  amazon   bezos is all in on blm ',
#  'children in distress project  feat  rez sps kings  fez taylor  royalty bourne    https   t co ex0qmboy via  amazon',
#  'used in my videos  tekpower tp01m https   t co pl0ztykiq  affiliatelink  ad portable handheld variable dc power   https   t co xvtzsrcal',
#  ' ratedmishra  shieldvoc  amazonhelp  amazon i hope you don t mind me chiming in  you ve already tried contacting th   https   t co 0djiyb1vj',
#  'hi guys   casio women s vintage la0wga 1df daily al    by casio https   t co rhsodzhjo via  amazon  tv follow tr   https   t co kqgnfvhq',
#  ' carsten11  davideoleary  mkmalarkey  amazonstudios  sptv  foxtv  tvnow  thecw  hbo  starz  syfy  amazon the fina   https   t co 0awfpjsg',
#  'rt  aclu  your turn   amazon and  microsoft  https   t co zaucxkllw',
#  'creating text that gives nightmares   i know that s my goal    nightmares  horror  writingfiction  where nightmares   https   t co cyira1zmox',
#  'so all protestors don t want  b lumped in with the rioters  all black people don t want  b lumped in with gangban   https   t co ihh0zrksl',
#  'multifunctional tactical defense  pen     tactical  titanium pen for safety includes nd  ink refill  amazon https   t co t1tfmahjk',
#  'descendants of shaolin  feat  mc oneline   explicit  keepazovdafunk https   t co xoxhdtmul via  amazon',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  'rt  newbergsean  weird stort shories by sean newberg https   t co kbekkajenm via  amazon   read free free free on  kindleunlimited or just  ',
#  'rt  1hariprakash1   amazon  jeffbezos black lives matter is not for black lives  it s an anti american anti capitalist org  it never spea  ',
#  'lube life https   t co nom1scfm via  amazon',
#  'rt  juliancastro  using facial recognition software as mass surveillance for law enforcement is a dangerous violation of human rights that  ',
#  ...]

# %%
new_texts = tokenizer.texts_to_sequences(new_texts)

# %%
new_texts = pad_sequences(new_texts, maxlen=MAX_LENGTH)

# %%
new_df['Sent2']=(new_df['Sentiment']+1)/2

# %%
new_df.head()
# Out:
#    Unnamed: 0      tweet_id  \
# 0           0  1.270000e+18
# 1           1  1.270000e+18
# 2           2  1.270000e+18
# 3           3  1.270000e+18
# 4           4  1.270000e+18
#
#                                                 text  Sentiment  Sent2
# 0  Yep, @amazon real easy to cancel now. I suppor...       -1.0    0.0
# 1  @amazon disgusting. Real classy Amazon.   @nyp...       -1.0    0.0
# 2  Check out this Amazon deal: #SamsungGalaxy S10...        0.0    0.5
# 3  RT @KennethCFilson: A Ripple In The Darkness b...        0.0    0.5
# 4  @midgets_levil @krokdrib @Jaxx702 @Marir65Ruiz...        0.0    0.5

# %%
preds_new = model.predict(new_texts)

# %%
preds_new[:10]
# Out:
# array([[0.52317655],
#        [0.2707116 ],
#        [0.39963853],
#        [0.61424214],
#        [0.5699257 ],
#        [0.2879994 ],
#        [0.84445506],
#        [0.59338176],
#        [0.11698467],
#        [0.5699257 ]], dtype=float32)

# %%
preds2=preds_new

# %%
for i in range(len(preds2)):
    if preds2[i]>0.3 and preds2[i]<0.7:
        preds2[i]=0.5
    elif preds2[i]<=0.3:
        preds2[i]=0.0
    elif preds2[i]>=0.7:
        preds2[i]=1.0

# %%
arr_sent=new_df.Sent2.to_numpy()

# %%
np.shape(arr_sent)
#type(preds2)np.shape(arr_sent)
#np.shape(preds2)
# Out:
# (3309,)

# %%
np.reshape(preds2,np.shape(arr_sent))
# Out:
# array([0.5, 0. , 0.5, ..., 0.5, 0.5, 0.5], dtype=float32)

# %%
accuracy_score(arr_sent, 1*preds2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-120d8c8ff353> in <module>
# ----> 1 accuracy_score(arr_sent, 1*preds2)
#
# ~\Anaconda32\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# ~\Anaconda32\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      70     """
#      71     check_consistent_length(y_true, y_pred)
# ---> 72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#      74
#
# ~\Anaconda32\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     282     if y.dtype.kind == 'f' and np.any(y != y.astype(int)):
#     283         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 284         _assert_all_finite(y)
#     285         return 'continuous' + suffix
#     286
#
# ~\Anaconda32\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
print('Accuracy on the test set: {:0.4}'.format(accuracy_score(arr_sent, preds2)))
#print('F1 score on the test set: {:0.4}'.format(f1_score(new_df['Sent2'], preds)))
#print('ROC AUC score: {:0.4}'.format(roc_auc_score(new_df['Sent2'], preds)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-c6e053d01747> in <module>
# ----> 1 print('Accuracy on the test set: {:0.4}'.format(accuracy_score(arr_sent, preds2)))
#       2 #print('F1 score on the test set: {:0.4}'.format(f1_score(new_df['Sent2'], preds)))
#       3 #print('ROC AUC score: {:0.4}'.format(roc_auc_score(new_df['Sent2'], preds)))
#
# ~\Anaconda32\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# ~\Anaconda32\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      70     """
#      71     check_consistent_length(y_true, y_pred)
# ---> 72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#      74
#
# ~\Anaconda32\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     282     if y.dtype.kind == 'f' and np.any(y != y.astype(int)):
#     283         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 284         _assert_all_finite(y)
#     285         return 'continuous' + suffix
#     286
#
# ~\Anaconda32\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
